# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_json(r"C:\Users\SKAN\Downloads\archive (12)\News_Category_Dataset_v3.json",lines=True)

# %%
df.to_csv(r"C:\Users\SKAN\Downloads\archive (12)\News_Category_Dataset_v3.csv")

# %%
df1=pd.read_csv(r"C:\Users\SKAN\Downloads\archive (12)\News_Category_Dataset_v3.csv")

# %%
df1
# Out:
#         Unnamed: 0                                               link  \
# 0                0  https://www.huffpost.com/entry/covid-boosters-...
# 1                1  https://www.huffpost.com/entry/american-airlin...
# 2                2  https://www.huffpost.com/entry/funniest-tweets...
# 3                3  https://www.huffpost.com/entry/funniest-parent...
# 4                4  https://www.huffpost.com/entry/amy-cooper-lose...
# ...            ...                                                ...
# 209522      209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523      209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524      209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525      209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526      209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# ...

# %%
df1.shape
# Out:
# (209527, 7)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209527 entries, 0 to 209526
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         209527 non-null  int64
#  1   link               209527 non-null  object
#  2   headline           209521 non-null  object
#  3   category           209527 non-null  object
#  4   short_description  189815 non-null  object
#  5   authors            172109 non-null  object
#  6   date               209527 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 11.2+ MB

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0               0
# link                     0
# headline                 6
# category                 0
# short_description    19712
# authors              37418
# date                     0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0           0
# link                 0
# headline             0
# category             0
# short_description    0
# authors              0
# date                 0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1["category"].value_counts()
# Out:
# POLITICS          29685
# ENTERTAINMENT     13463
# WELLNESS          12944
# TRAVEL             8024
# STYLE & BEAUTY     7275
# PARENTING          6520
# HEALTHY LIVING     5072
# QUEER VOICES       4700
# FOOD & DRINK       4527
# BUSINESS           4373
# COMEDY             3934
# SPORTS             3608
# HOME & LIVING      3523
# PARENTS            3491
# BLACK VOICES       3313
# IMPACT             2945
# WOMEN              2921
# WORLD NEWS         2678
# THE WORLDPOST      2198
# MEDIA              2105
# CRIME              2093
# WEIRD NEWS         1965
# TASTE              1891
# RELIGION           1780
# WEDDINGS           1705
# DIVORCE            1695
# GREEN              1682
# TECH               1681
# MONEY              1539
# STYLE              1535
# SCIENCE            1428
# ARTS & CULTURE     1307
# WORLDPOST          1242
# U.S. NEWS          1093
# FIFTY              1042
# GOOD NEWS           917
# EDUCATION           893
# LATINO VOICES       878
# ...

# %%
df1["category"].replace("BLACK VOICES","POLITICS",inplace=True)
df1["category"].replace("THE WORLDPOST","POLITICS",inplace=True)
df1["category"].replace("WORLD NEWS","POLITICS",inplace=True)
df1["category"].replace("WORLDPOST","POLITICS",inplace=True)
df1["category"].replace("GOOD NEWS","POLITICS",inplace=True)
df1["category"].replace("U.S. NEWS","POLITICS",inplace=True)
df1["category"].replace("LATINO VOICES","POLITICS",inplace=True)

# %%
df1["category"].replace("MONEY","BUSINESS",inplace=True)

# %%
df1["category"].replace("STYLE & BEAUTY","ENTERTAINMENT",inplace=True)
df1["category"].replace("COMEDY","ENTERTAINMENT",inplace=True)
df1["category"].replace("WEDDINGS","ENTERTAINMENT",inplace=True)
df1["category"].replace("MEDIA","ENTERTAINMENT",inplace=True)
df1["category"].replace("STYLE","ENTERTAINMENT",inplace=True)
df1["category"].replace("ARTS","ENTERTAINMENT",inplace=True)
df1["category"].replace("ENVIRONMENT","ENTERTAINMENT",inplace=True)
df1["category"].replace("ARTS & CULTURE","ENTERTAINMENT",inplace=True)
df1["category"].replace("COLLEGE","ENTERTAINMENT",inplace=True)
df1["category"].replace("CULTURE & ARTS","ENTERTAINMENT",inplace=True)
df1["category"].replace("EDUCATION","ENTERTAINMENT",inplace=True)

# %%
df1["category"].replace("SCIENCE","TECHNOLOGY",inplace=True)
df1["category"].replace("TECH","TECHNOLOGY",inplace=True)

# %%
df1["category"].replace("TRAVEL","OTHERS",inplace=True)
df1["category"].replace("PARENTING","OTHERS",inplace=True)
df1["category"].replace("QUEER VOICES","OTHERS",inplace=True)
df1["category"].replace("PARENTS","OTHERS",inplace=True)
df1["category"].replace("WOMEN","OTHERS",inplace=True)
df1["category"].replace("CRIME","OTHERS",inplace=True)
df1["category"].replace("IMPACT","OTHERS",inplace=True)
df1["category"].replace("DIVORCE","OTHERS",inplace=True)
df1["category"].replace("WEIRD NEWS","OTHERS",inplace=True)
df1["category"].replace("GREEN","OTHERS",inplace=True)
df1["category"].replace("RELIGION","OTHERS",inplace=True)
df1["category"].replace("FIFTY","OTHERS",inplace=True)

# %%
df1["category"].replace("WELLNESS","HEALTH",inplace=True)
df1["category"].replace("HEALTHY LIVING ","HEALTH",inplace=True)
df1["category"].replace("FOOD & DRINK","HEALTH",inplace=True)
df1["category"].replace("HOME & LIVING","HEALTH",inplace=True)
df1["category"].replace("TASTE","HEALTH",inplace=True)
df1["category"].replace("HEALTHY LIVING","HEALTH",inplace=True)

# %%
df1["category"].value_counts()
# Out:
# POLITICS         42004
# OTHERS           38858
# ENTERTAINMENT    35411
# HEALTH           27957
# BUSINESS          5912
# SPORTS            3608
# TECHNOLOGY        3109
# Name: category, dtype: int64

# %%
df1['category_id'] = df1['category'].factorize()[0]
df1.head()
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.huffpost.com/entry/covid-boosters-...
# 1           1  https://www.huffpost.com/entry/american-airlin...
# 2           2  https://www.huffpost.com/entry/funniest-tweets...
# 3           3  https://www.huffpost.com/entry/funniest-parent...
# 4           4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline       category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...       POLITICS
# 1  American Airlines Flyer Charged, Banned For Li...       POLITICS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...  ENTERTAINMENT
# 3  The Funniest Tweets From Parents This Week (Se...         OTHERS
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...       POLITICS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'link', 'headline', 'category', 'short_description',
#        'authors', 'date', 'category_id'],
#       dtype='object')

# %%
df1.drop(["Unnamed: 0","link","date","authors","short_description"],axis=1,inplace=True)

# %%
df1
# Out:
#                                                  headline       category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...       POLITICS
# 1       American Airlines Flyer Charged, Banned For Li...       POLITICS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...  ENTERTAINMENT
# 3       The Funniest Tweets From Parents This Week (Se...         OTHERS
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...       POLITICS
# ...                                                   ...            ...
# 209517                      Good Games -- Is It possible?     TECHNOLOGY
# 209518    Google+ Now Open for Teens With Some Safeguards     TECHNOLOGY
# 209519                                           Web Wars     TECHNOLOGY
# 209521         Watch The Top 9 YouTube Videos Of The Week     TECHNOLOGY
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...     TECHNOLOGY
#
#         category_id
# 0                 0
# 1                 0
# 2                 1
# ...

# %% [markdown]
# # EDA

# %%
df1['category'].value_counts().plot(kind = "bar", color = ["pink", "orange", "red", "yellow", "blue","green","cyan"])
plt.xlabel("Category of data")
plt.title("Visulaize numbers of Category of data")
plt.show()

# %%
fig = plt.figure(figsize = (5,5))
colors = ["skyblue"]
pie = plt.pie(df1["category_id"].value_counts(), labels = ["POLITICS","OTHERS","ENTERTAINMENT","HEALTH","BUSINESS","SPORTS","TECHNOLOGY"],
              autopct = "%1.1f%%",
              shadow = True,
              colors = colors,
              startangle = 45,
              explode = (0.05, 0.05, 0.05, 0.05,0.05,0.05,0.05))

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SKAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SKAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SKAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stop = set(stopwords.words('english'))

# %%
df1.groupby("category")["category_id"].count()
# Out:
# category
# BUSINESS          5912
# ENTERTAINMENT    35411
# HEALTH           27957
# OTHERS           38858
# POLITICS         42004
# SPORTS            3608
# TECHNOLOGY        3109
# Name: category_id, dtype: int64

# %%
POLITICS = df1[df1['category_id'] == 0]

POLITICS = POLITICS['headline']

ENTERTAINMENT = df1[df1['category_id'] == 1]

ENTERTAINMENT = ENTERTAINMENT['headline']

OTHERS = df1[df1['category_id'] == 2]

OTHERS = OTHERS['headline']

TECHNOLOGY = df1[df1['category_id'] == 3]

TECHNOLOGY= TECHNOLOGY['headline']

SPORTS= df1[df1['category_id'] == 4]

SPORTS= SPORTS['headline']

HEALTH= df1[df1['category_id'] == 5]

HEALTH= HEALTH['headline']

BUSINESS= df1[df1['category_id'] == 6]

BUSINESS= BUSINESS['headline']

# %%
def wordcloud_draw(dataset,color='black'):

    words = ' '.join(dataset)

    cleaned_word = ' '.join([word for word in words.split()

    if (word != 'news' and word != 'text')])

    wordcloud = WordCloud(stopwords = stop,

    background_color = color,

    width = 2500, height = 2500).generate(cleaned_word)

    plt.figure(1, figsize = (10,7))

    plt.imshow(wordcloud)

    plt.axis("off")

    plt.show()

# %%
print("POLITICS Related Words:",end="")

wordcloud_draw(POLITICS)
# Out:
# POLITICS Related Words:

# %%
print("ENTERTAINMENT Related Words:",end="")

wordcloud_draw(ENTERTAINMENT)
# Out:
# ENTERTAINMENT Related Words:

# %%
print("TECHNOLOGY Related Words:",end="")

wordcloud_draw(TECHNOLOGY)
# Out:
# TECHNOLOGY Related Words:

# %%
print("SPORTS Related Words:",end="")

wordcloud_draw(SPORTS)
# Out:
# SPORTS Related Words:

# %%
print("HEALTH Related Words:",end="")

wordcloud_draw(HEALTH)
# Out:
# HEALTH Related Words:

# %%
print("BUSINESS Related Words:",end="")

wordcloud_draw(BUSINESS)
# Out:
# BUSINESS Related Words:

# %%
print("OTHERS Related Words:",end="")

wordcloud_draw(OTHERS)
# Out:
# OTHERS Related Words:

# %%
# convert in lowercase
df1['headline']=df1['headline'].apply(lambda x:" ".join(x.lower() for x in x.split()))
df1['headline'].head()
# Out:
# 0    over 4 million americans roll up sleeves for o...
# 1    american airlines flyer charged, banned for li...
# 2    23 of the funniest tweets about cats and dogs ...
# 3    the funniest tweets from parents this week (se...
# 4    woman who called cops on black bird-watcher lo...
# Name: headline, dtype: object

# %%
#Remove punctuation marks
df1['headline']=df1['headline'].str.replace('[^\w\s]','')
df1['headline'].head()
# Out:
# 0    over 4 million americans roll up sleeves for o...
# 1    american airlines flyer charged banned for lif...
# 2    23 of the funniest tweets about cats and dogs ...
# 3    the funniest tweets from parents this week sep...
# 4    woman who called cops on black birdwatcher los...
# Name: headline, dtype: object

# %%
# removal of stopwords
df1['headline']=df1['headline'].apply(lambda x:" ".join(x for x in x.split() if x not in stop))
df1['headline'].head()
# Out:
# 0    4 million americans roll sleeves omicrontarget...
# 1    american airlines flyer charged banned life pu...
# 2          23 funniest tweets cats dogs week sept 1723
# 3               funniest tweets parents week sept 1723
# 4    woman called cops black birdwatcher loses laws...
# Name: headline, dtype: object

# %%
#lemmatization
wordnet = WordNetLemmatizer()
df1["headline"].apply(lambda x: " ".join([wordnet.lemmatize(word)for word in x.split()]))
df1["headline"].head()
# Out:
# 0    4 million americans roll sleeves omicrontarget...
# 1    american airlines flyer charged banned life pu...
# 2          23 funniest tweets cats dogs week sept 1723
# 3               funniest tweets parents week sept 1723
# 4    woman called cops black birdwatcher loses laws...
# Name: headline, dtype: object

# %% [markdown]
# # After cleaning the Text

# %%
df1
# Out:
#                                                  headline       category  \
# 0       4 million americans roll sleeves omicrontarget...       POLITICS
# 1       american airlines flyer charged banned life pu...       POLITICS
# 2             23 funniest tweets cats dogs week sept 1723  ENTERTAINMENT
# 3                  funniest tweets parents week sept 1723         OTHERS
# 4       woman called cops black birdwatcher loses laws...       POLITICS
# ...                                                   ...            ...
# 209517                                good games possible     TECHNOLOGY
# 209518                       google open teens safeguards     TECHNOLOGY
# 209519                                           web wars     TECHNOLOGY
# 209521                    watch top 9 youtube videos week     TECHNOLOGY
# 209522  rim ceo thorsten heins significant plans black...     TECHNOLOGY
#
#         category_id
# 0                 0
# 1                 0
# 2                 1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, classification_report,roc_curve,roc_auc_score
from sklearn.naive_bayes import GaussianNB

# %%
X=df1["headline"].values
y=df1["category_id"].values

# %%
X
# Out:
# array(['4 million americans roll sleeves omicrontargeted covid boosters',
#        'american airlines flyer charged banned life punching flight attendant video',
#        '23 funniest tweets cats dogs week sept 1723', ..., 'web wars',
#        'watch top 9 youtube videos week',
#        'rim ceo thorsten heins significant plans blackberry'],
#       dtype=object)

# %%
y
# Out:
# array([0, 0, 1, ..., 3, 3, 3], dtype=int64)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vec1=TfidfVectorizer(max_features=2500,min_df=7,max_df=0.8)
vec_X=vec1.fit_transform(X).toarray()

# %%
X_train,X_test,y_train,y_test=train_test_split(vec_X,y,test_size=0.2,random_state=0)

# %%
print(vec_X.shape,X_train.shape,X_test.shape)
# Out:
# (156859, 2500) (125487, 2500) (31372, 2500)

# %%
svc = SVC()

# %%
svc.fit(X_train,y_train)

# %%
y_pred=svc.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74      8313
#            1       0.68      0.65      0.66      7006
#            2       0.58      0.63      0.61      7843
#            3       0.57      0.25      0.34       629
#            4       0.61      0.39      0.48       693
#            5       0.64      0.70      0.67      5756
#            6       0.56      0.28      0.37      1132
#
#     accuracy                           0.65     31372
#    macro avg       0.62      0.52      0.55     31372
# weighted avg       0.65      0.65      0.65     31372

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y1_pred=model.predict(X_test)

# %%
print(classification_report(y_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.72      8313
#            1       0.64      0.61      0.62      7006
#            2       0.58      0.58      0.58      7843
#            3       0.47      0.20      0.28       629
#            4       0.56      0.34      0.43       693
#            5       0.59      0.69      0.63      5756
#            6       0.48      0.25      0.33      1132
#
#     accuracy                           0.62     31372
#    macro avg       0.57      0.49      0.51     31372
# weighted avg       0.62      0.62      0.62     31372

# %%
model1=GaussianNB()

# %%
model1.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y2_pred=model1.predict(X_test)

# %%
print(classification_report(y_test,y2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.20      0.32      8313
#            1       0.79      0.19      0.30      7006
#            2       0.69      0.07      0.12      7843
#            3       0.04      0.79      0.07       629
#            4       0.06      0.67      0.11       693
#            5       0.57      0.15      0.24      5756
#            6       0.09      0.30      0.14      1132
#
#     accuracy                           0.18     31372
#    macro avg       0.44      0.34      0.19     31372
# weighted avg       0.67      0.18      0.24     31372

# %% [markdown]
# # Support Vector Classifier gives the better accuracy
